# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 百度北京冬奥会

# %%
df1 = pd.read_excel("百度热搜指数-资讯关注.xlsx")
df2 = pd.read_excel("百度搜索指数-北京冬奥会.xlsx")

# %%
plt.figure(figsize=(8, 6), dpi=200)
plt.rcParams['font.sans-serif'] = ['SimHei']

plt.xlabel("日期")
plt.ylabel("指数")

plt.plot(df1["时间"],df1["资讯关注"],label='"北京冬奥会"资讯关注度')
plt.plot(df2["时间"],df2["搜索指数"],label='"北京冬奥会"搜索指数')
plt.plot(df3["时间"],df3["资讯指数"],label='"冰墩墩"资讯关注度')
plt.plot(df3["时间"],df3["搜索指数"],label='"冰墩墩"搜索指数')
plt.legend()
plt.savefig("2.png")

# %%
num = df1["资讯关注"]
y1 = num[0:3]
y2 = num[3:33]
y3 = num[33:64]
y4 = num[64:95]
y5 = num[95:123]
y6 = num[123:]

# %%
plt.figure(figsize=(10, 6.18), dpi=120)
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.xlabel("日期")
plt.ylabel("指数")
plt.plot(range(29, 32), y1, label="21年10月")
plt.plot(range(1, 31), y2, label="21年11月", linestyle="--")
plt.plot(range(1, 32), y3, label="21年12月", linestyle=":")
plt.plot(range(1, 32), y4, label="22年1月")
plt.plot(range(1, 29), y5, label="22年2月", linestyle="-")
plt.plot(range(1, 11), y6, label="22年3月")
plt.xticks(range(0, 32), range(0, 32))
plt.legend()
plt.savefig("2.png")
plt.show()

# %% [markdown]
# # 冰墩墩

# %%
df3 = pd.read_excel("冰墩墩百度搜索指数.xlsx")

# %%
plt.figure(figsize=(15, 6), dpi=100)
plt.rcParams['font.sans-serif'] = ['SimHei']

plt.xlabel("日期")
plt.ylabel("指数")

plt.plot(df3["时间"],df3["资讯指数"],label='"冰墩墩"资讯关注度')
plt.plot(df3["时间"],df3["搜索指数"],label='"冰墩墩"搜索指数')

plt.legend()
plt.savefig("3.png")
plt.show()

# %% [markdown]
# # 冬奥会关注度比较

# %%
df4 = pd.read_csv("冬奥会关注度比较.csv",index_col='time')

# %%
plt.figure(figsize=(8, 6), dpi=200)
plt.rcParams['font.sans-serif'] = ['SimHei']
xwhere=['2004-06','2005-06','2006-06','2007-06','2008-06','2009-06','2010-06','2011-06','2012-06','2013-06','2014-06','2015-06','2016-06','2017-06','2018-06','2019-06','2020-06','2021-06','2022-06']
plt.plot(df4.index,df4.x,label='"北京冬奥会"谷歌搜索热度')
plt.plot(df4.index,df4.y,label='"平昌冬奥会"谷歌搜索热度')
plt.plot(df4.index,df4.z,label='"索契冬奥会"谷歌搜索热度')
plt.plot(df4.index,df4.w,label='"温哥华冬奥会"谷歌搜索热度')
plt.xticks(xwhere,xwhere,rotation=40)
plt.legend()
plt.savefig("5.png")
plt.show()

# %%
df3.tail()
# Out:
#            时间   搜索指数   资讯指数
# 73 2022-03-30  22300  17842
# 74 2022-03-31  21545  29478
# 75 2022-04-01  20225   6964
# 76 2022-04-02  20724   7452
# 77 2022-04-03  23806   5019

# %%
df1["资讯关注"].sum()
# Out:
# 301610262

# %%
df2["搜索指数"].sum()
# Out:
# 60061823

# %%
df3["搜索指数"].sum()
# Out:
# 14748745

# %%
df3["资讯指数"].sum()
# Out:
# 92909171
